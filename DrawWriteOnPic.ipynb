# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('lenna.jpg',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
#plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
import numpy as np
import cv2
arr_zeros = np.zeros((512,512,3) ,np.uint8)
drawLine = cv2.line(arr_zeros,(1,1) ,(200,200) ,(0,0,255) ,5)
drawCircle = cv2.circle(arr_zeros ,(250 ,250) ,70 ,(0,255,0),4)
drawRectangle = cv2.rectangle(arr_zeros , (300,300),(450,450) ,(255,0,0),3)
drawElipse= cv2.ellipse(arr_zeros ,(250 ,250),(50,50),0,0,180,(255,255,0),5)
drawElipsew= cv2.ellipse(arr_zeros ,(250 ,250),(50,50),225,0,20,(255,0,0),5)

font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(arr_zeros,'OpenCV',(10,400), font, 2,(255,150,255),6)
cv2.imshow("img" ,arr_zeros)
cv2.waitKey(0)
cv2.destroyAllWindows()
